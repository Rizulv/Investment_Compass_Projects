# %%
import requests

# Your News API key
api_key = '6ac56b0c666d4b7db3941f68dd2995d0'

# Base URL for News API
url = 'https://newsapi.org/v2/everything'

# Parameters for the API request
params = {
    'q': 'Tata Motors',  # Query for articles related to Tata Motors
    'apiKey': api_key,
    'pageSize': 100,  # Number of articles to fetch (max 100 per request)
    'language': 'en'  # Fetch articles in English
}

# Make the API request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    # Extract the articles
    articles = data['articles']
    # Print the titles of the articles
    for article in articles:
        print(article['title'])
else:
    print('Failed to fetch articles. Status code:', response.status_code)
# Out:
# Tata Motors to focus on manufacturing bigger vehicles
# Tata Motors to separate passenger, commercial vehicle businesses into two listed firms
# Tata Motors, Tata Investment, other group stocks soar up to 15% on buzz over Tata Sons IPO
# Moneycontrol Pro Panorama | What next for Tata Motors after demerger?
# Reduce Tata Motors; target of Rs 950: Emkay Global Financial
# Reduce Tata Motors; target of Rs 901: ICICI Securities
# Tata Motors stock gains on Moody#39;s positive outlook post-demerger
# Mid-day Mood | Sensex, Nifty snap 4-day win streak to trade lower
# Tata Motors shares pick up on Rs 9,000-crore plant deal with Tamil Nadu
# Buzzing Stocks: Tata Motors, IIFL Finance, AU Small Finance Bank, NTPC and others in news
# Taking Stock: Market ends with modest gain amid high volatility; Nifty gains 3% in Feb expiry
# Tata Motors sees MFs selling around Rs 1,441 crore stake in January
# Tata Motors stock gains 3% on launch of new of CVs in South Africa
# ...

# %%
pip install textblob
# Out:
# ...
#      -------------------------------------- 626.3/626.3 kB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 1.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# List of news titles
news_titles = [
   "Tata Motors to focus on manufacturing bigger vehicles",
"Tata Motors to separate passenger, commercial vehicle businesses into two listed firms",
"Tata Motors, Tata Investment, other group stocks soar up to 15% on buzz over Tata Sons IPO",
"Moneycontrol Pro Panorama | What next for Tata Motors after demerger?",
"Reduce Tata Motors; target of Rs 950: Emkay Global Financial",
"Reduce Tata Motors; target of Rs 901: ICICI Securities",
"Tata Motors stock gains on Moody#39;s positive outlook post-demerger",
"Mid-day Mood | Sensex, Nifty snap 4-day win streak to trade lower",
"Tata Motors shares pick up on Rs 9,000-crore plant deal with Tamil Nadu",
"Buzzing Stocks: Tata Motors, IIFL Finance, AU Small Finance Bank, NTPC and others in news",
"Taking Stock: Market ends with modest gain amid high volatility; Nifty gains 3% in Feb expiry",
"Tata Motors sees MFs selling around Rs 1,441 crore stake in January",
"Tata Motors stock gains 3% on launch of new of CVs in South Africa",
"Tata confirms Somerset site as location for UK battery factory",
"Taking Stock: Sensex, Nifty at a new high on blowout GDP data, Nifty Bank reclaims 47,000",
"Tata Motors to set up vehicle manufacturing facility in Tamil Nadu",
"Tata Sons may be valued at up to $96 billion in IPO: Spark",
"Tata Motors’ demerger is backed by a dual-lane strategy",
"Taking Stock: Market ends flat after Nifty surpasses 22,500 for first time; mid-, small-caps gain",
"As Nifty touches 22,000, here are 3 breakout stocks worth looking at",
"Daily Voice: Expect Nifty at 25,363 by December; bullish on 7 stocks, says Amnish Agarwal of Prabhudas Lilladher",
"India chip strategy makes progress with $21billion in proposals",
"Car design legend Marcello Gandini dies at 85",
"Mid-day Mood | Nifty, Sensex inch higher on buying in auto stocks, focus onÂ fundamentals",
"Tata Motors, hello, electric mobility plan",
"CIE Automotive India falls 2% after net profit slips 9% for Dec quarter",
"Tata Motors demerge the company into two separate listed companies",
"India’s Most Expensive Vintage Cars: The Oberoi Concours in Udaipur",
"IT, auto stocks trigger revival as Sensex jumps 305 points, reclaims 73,000",
"Moneycontrol Pro Panorama | FAME II extension: a proactive move to turbocharge EV demand",
"Moneycontrol Pro Market Outlook | Structural weakness persists as the market climbs higher",
"Tata Motors Shares Rise Sharply After Plan to Split Into Two Listed Companies",
"Commercial Vehicle Market revenue to surpass USD 50 Trillion by 2035, says Research Nester",
"Taking Stock: Nifty hits fresh all-time high, Sensex gains 535 points on sharp pulback",
"Nifty, Sensex close with minor gains after hitting new highs; market in consolidation",
"Popular Vehicles and Services IPO opens on March 12, fresh issue size at Rs 250 crore",
"Saturday Trading Mood: New all-time highs, smoother operations, higher stability",
"Popular Vehicles sets price band at Rs 280-295 for its Rs 600-crore IPO",
"Hot Stocks: Brokerage view on Siemens, IIFL Finance, Max Healthcare and Tata Motors",
"Mid-day market update: Nifty unchanged, Sensex up 0.11%",
"Tata Group eyes mega $1-2 billion IPO for its EV business: Report",
"Stocks that will see action today (March 14, 2023)",
"Tata Motors shares take breather after recent rally, trade flat",
"Tata Motors may accelerate as demerger decision boosts brokerages",
"Ford likely to drive back to India with EV focus",
"Neutral Tata Motors; target of Rs 1000: Motilal Oswal",
"Tata Motors to hike commercial vehicle prices by up to 2%",
"Tata Motors to hike price of commercial vehicles by 2% from April 1",
"Tata Sons may command market valueof ₹8-lakh crore in IPO: Spark PMW",
"Stock market update: Stocks that hit 52-week highs on NSE in today's trade",
"INDIA STOCKS-Indian shares snap winning run on IT slide; surge in Tata Motors limits losses",
"ET Market Watch: Sensex and Nifty close flat, all eyes on inflation data",
"Indias Tata Group mulls battery business spinoff - Bloomberg News",
    # Add more titles here
]

# Analyze sentiment of each news title
sentiments = []
for title in news_titles:
    analysis = TextBlob(title)
    sentiments.append(analysis.sentiment.polarity)

# Calculate average sentiment
average_sentiment = sum(sentiments) / len(sentiments)
print("Average Sentiment:", average_sentiment)

# Interpret the average sentiment
if average_sentiment > 0:
    print("Overall Positive Sentiment")
elif average_sentiment < 0:
    print("Overall Negative Sentiment")
else:
    print("Neutral Sentiment")
# Out:
# Average Sentiment: 0.08419166666666668
# Overall Positive Sentiment

# %%
import pandas as pd
from textblob import TextBlob

# List of news titles
news_titles = [
    "Tata Motors to focus on manufacturing bigger vehicles",
"Tata Motors to separate passenger, commercial vehicle businesses into two listed firms",
"Tata Motors, Tata Investment, other group stocks soar up to 15% on buzz over Tata Sons IPO",
"Moneycontrol Pro Panorama | What next for Tata Motors after demerger?",
"Reduce Tata Motors; target of Rs 950: Emkay Global Financial",
"Reduce Tata Motors; target of Rs 901: ICICI Securities",
"Tata Motors stock gains on Moody#39;s positive outlook post-demerger",
"Mid-day Mood | Sensex, Nifty snap 4-day win streak to trade lower",
"Tata Motors shares pick up on Rs 9,000-crore plant deal with Tamil Nadu",
"Buzzing Stocks: Tata Motors, IIFL Finance, AU Small Finance Bank, NTPC and others in news",
"Taking Stock: Market ends with modest gain amid high volatility; Nifty gains 3% in Feb expiry",
"Tata Motors sees MFs selling around Rs 1,441 crore stake in January",
"Tata Motors stock gains 3% on launch of new of CVs in South Africa",
"Tata confirms Somerset site as location for UK battery factory",
"Tatas to list electric vehicles business",
"Tatas to list electric vehicles business",
"Tata stock zooms 34% in 3 days amid rising speculations over Tata Sons IPO",
"India's Tata Motors plans to demerge business into two separate companies",
"India's Tata Motors to hike commercial vehicle prices by up to 2%",
"India's Tata Motors jumps on plans to split into two listed firms",
"Technical Breakout Stocks: How to trade Tata Consumer, Tata Motors, Rainbow Medicare on Thursday",
"Technical Breakout Stocks: How to trade Tata Investment Corp, Tata Motors and SBI on Wednesday",
"Nifty Auto paces up ahead of Feb sales data; Tata Motors, Maruti in fast lane",
"Tata Motors passenger vehicles can definitely bridge the gap with Maruti: Ashwin Patil",
"Tata Motors stock hits record on split-up plan",
"Stock market update: Stocks that hit 52-week lows on NSE",
"Tata Motors surges on demerger, IIFL dives 20%",
"Tata Chemicals and its stake in Tata Sons: Is the recent upside in shares justified?",
"Tata Motors demerge the company into two separate listed companies",
"India’s Most Expensive Vintage Cars: The Oberoi Concours in Udaipur",
"IT, auto stocks trigger revival as Sensex jumps 305 points, reclaims 73,000",
"Moneycontrol Pro Panorama | FAME II extension: a proactive move to turbocharge EV demand",
"Moneycontrol Pro Market Outlook | Structural weakness persists as the market climbs higher",
"Tata Motors Shares Rise Sharply After Plan to Split Into Two Listed Companies",
"Commercial Vehicle Market revenue to surpass USD 50 Trillion by 2035, says Research Nester",
"Taking Stock: Nifty hits fresh all-time high, Sensex gains 535 points on sharp pulback",
"Nifty, Sensex close with minor gains after hitting new highs; market in consolidation",
"Popular Vehicles and Services IPO opens on March 12, fresh issue size at Rs 250 crore",
"Saturday Trading Mood: New all-time highs, smoother operations, higher stability",
"Popular Vehicles sets price band at Rs 280-295 for its Rs 600-crore IPO",
"Hot Stocks: Brokerage view on Siemens, IIFL Finance, Max Healthcare and Tata Motors",
"Mid-day market update: Nifty unchanged, Sensex up 0.11%",
"Tata Group eyes mega $1-2 billion IPO for its EV business: Report",
"Stocks that will see action today (March 14, 2023)",
"Tata Motors shares take breather after recent rally, trade flat",
"Tata Motors may accelerate as demerger decision boosts brokerages",
"Ford likely to drive back to India with EV focus",
"Neutral Tata Motors; target of Rs 1000: Motilal Oswal",
"Tata Motors to hike commercial vehicle prices by up to 2%",
"Tata Motors to hike price of commercial vehicles by 2% from April 1",
"Tata Sons may command market valueof ₹8-lakh crore in IPO: Spark PMW",
"Stock market update: Stocks that hit 52-week highs on NSE in today's trade",
"INDIA STOCKS-Indian shares snap winning run on IT slide; surge in Tata Motors limits losses",
"ET Market Watch: Sensex and Nifty close flat, all eyes on inflation data",
"Indias Tata Group mulls battery business spinoff - Bloomberg News",
    # Your titles
]

# Analyze sentiment of each news title and store the results
articles_data = []
for title in news_titles:
    analysis = TextBlob(title)
    sentiment_score = analysis.sentiment.polarity
    if sentiment_score > 0:
        sentiment_category = 'Positive'
    elif sentiment_score < 0:
        sentiment_category = 'Negative'
    else:
        sentiment_category = 'Neutral'
    articles_data.append({
        'Title': title,
        'Sentiment Score': sentiment_score,
        'Sentiment Category': sentiment_category
    })

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(articles_data)

# Export the DataFrame to an Excel file
df.to_excel(r'C:\Users\A\Desktop\The Investment Compass\sentiment_analysis.xlsx', index=False)

print("Data exported to sentiment_analysis.xlsx")
# Out:
# Data exported to sentiment_analysis.xlsx
